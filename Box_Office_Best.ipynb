# %%
import pandas as pd
import datetime
from pathlib import Path
import lxml.html
import openpyxl

# %%
print("Start of Program: " + str(datetime.datetime.now().strftime("%I:%m %p")))
# Out:
# Start of Program: 08:02 AM

# %%
directory = Path.cwd()

# %%
directory
# Out:
# WindowsPath('C:/Users/Brian/PycharmProjects/notebooks')

# %%
url = "https://www.boxofficemojo.com/weekend/"

# %%
year = input("What year do you want to query on? ")

# %%
week = input("What week do you want to query on? Input format: ##")

# %%
timeperiod = year +'W'+ week
print(timeperiod)
# Out:
# 2024W06

# %%
url = "https://www.boxofficemojo.com/weekend/"+timeperiod+"/"

# %%
print(url)
# Out:
# https://www.boxofficemojo.com/weekend/2024W06/

# %%
movie_df = pd.read_html(url)[0]
movie_df.head(5)
# Out:
#    Rank LW            Release       Gross   %± LW Theaters Change Average  \
# 0     1  1            Argylle  $6,249,360  -64.2%     3605      -  $1,733
# 1     2  -  Lisa Frankenstein  $3,695,785       -     3144      -  $1,175
# 2     3  3      The Beekeeper  $3,398,372  -35.7%     3057   -220  $1,111
# 3     4  4              Wonka  $3,056,430  -34.7%     2764   -137  $1,105
# 4     5  5          Migration  $2,935,590    -30%     2684   -146  $1,093
#
#     Total Gross  Weeks                Distributor  New This Week  Estimated
# 0   $28,563,505      2         Universal Pictures          False      False
# 1    $3,695,785      1             Focus Features           True      False
# 2   $54,663,224      5  Metro-Goldwyn-Mayer (MGM)          False      False
# 3  $205,183,453      9               Warner Bros.          False      False
# 4  $110,065,035      8         Universal Pictures          False      False

# %%
dt_now = datetime.datetime.now()

movie_df['Datestamp'] = dt_now

# %%
print(movie_df.columns)
# Out:
# Index(['Rank', 'LW', 'Release', 'Gross', '%± LW', 'Theaters', 'Change',
#        'Average', 'Total Gross', 'Weeks', 'Distributor', 'New This Week',
#        'Estimated', 'Datestamp'],
#       dtype='str')

# %%
print(movie_df[['Rank','Release']])
# Out:
#     Rank                                     Release
# 0      1                                     Argylle
# 1      2                           Lisa Frankenstein
# 2      3                               The Beekeeper
# 3      4                                       Wonka
# 4      5                                   Migration
# ..   ...                                         ...
# 71    72                                    The Oath
# 72    73  One from the Heart: Reprise2024 Re-release
# 73    74            Stop Making Sense2023 Re-release
# 74    75                                   The Shift
# 75    76                               Godard Cinema
#
# [76 rows x 2 columns]

# %%
#Location_for_file_export1 = r'C:\Users\Brian\OneDrive\Desktop\Box_Office1.csv'
#df.to_csv(Location_for_file_export, index=False)


#Location_for_file_export2 = r'C:\Users\Brian\PycharmProjects\notebooks\data_output\Box_Office1.xlsx'
Location_for_file_export2 = Path.cwd() / 'data_output' / 'Box_Office1.xlsx'
movie_df.to_excel(Location_for_file_export2, index=False)
print("Saving to:", Location_for_file_export2.resolve())
# Out:
# Saving to: C:\Users\Brian\PycharmProjects\notebooks\data_output\Box_Office1.xlsx
# End of Program: 08:02 AM

# %%
print("End of Program: " + str(datetime.datetime.now().strftime("%I:%m %p")))
