# %%
import pandas as pd
import datetime
from pathlib import Path
import lxml.html
import openpyxl

# %%
print("Start of Program: " + str(datetime.datetime.now().strftime("%I:%m %p")))
# Out:
# Start of Program: 01:02 AM

# %%
directory = Path.cwd()

# %%
directory
# Out:
# PosixPath('/workspaces/movie_notebooks')

# %%
url = "https://www.boxofficemojo.com/weekend/"

# %%
year = input("What year do you want to query on? ")

# %%
week = input("What week do you want to query on? Input format: ##")

# %%
timeperiod = year +'W'+ week
print(timeperiod)
# Out:
# 2026W06

# %%
url = "https://www.boxofficemojo.com/weekend/"+timeperiod+"/"

# %%
print(url)
# Out:
# https://www.boxofficemojo.com/weekend/2026W06/

# %%
movie_df = pd.read_html(url)[0]
movie_df.head(5)
# Out:
#    Rank LW                              Release       Gross   %± LW  Theaters  \
# 0     1  1                            Send Help  $9,046,059  -52.6%      3475
# 1     2  -                             Solo Mio  $7,001,169       -      3052
# 2     3  2                            Iron Lung  $6,000,000  -66.3%      2930
# 3     4  -  Stray Kids: The dominATE Experience  $5,709,394       -      1724
# 4     5  -                              Dracula  $4,400,264       -      2050
#
#   Change Average  Total Gross  Weeks                          Distributor  \
# 0      -  $2,603  $34,885,807      2  Walt Disney Studios Motion Pictures
# 1      -  $2,293   $7,001,169      1                                Angel
# 2    -85  $2,047  $30,800,000      2                           Markiplier
# 3      -  $3,311   $5,709,394      1                Bleecker Street Media
# 4      -  $2,146   $4,400,264      1               Vertical Entertainment
#
#    New This Week  Estimated
# 0          False      False
# 1           True      False
# 2          False       True
# 3           True      False
# 4           True      False

# %%
dt_now = datetime.datetime.now()

movie_df['Datestamp'] = dt_now

# %%
print(movie_df.columns)
# Out:
# Index(['Rank', 'LW', 'Release', 'Gross', '%± LW', 'Theaters', 'Change',
#        'Average', 'Total Gross', 'Weeks', 'Distributor', 'New This Week',
#        'Estimated', 'Datestamp'],
#       dtype='str')

# %%
print(movie_df[['Rank','Release']])
# Out:
#     Rank                                      Release
# 0      1                                    Send Help
# 1      2                                     Solo Mio
# 2      3                                    Iron Lung
# 3      4          Stray Kids: The dominATE Experience
# 4      5                                      Dracula
# ..   ...                                          ...
# 68    69               Killer of Sheep2025 Re-release
# 69    70  The Business of Fancydancing2025 Re-release
# 70    71          Put Your Soul on Your Hand and Walk
# 71    72                                        Seeds
# 72    73                                 Fuck My Son!
#
# [73 rows x 2 columns]

# %%
#Location_for_file_export1 = r'C:\Users\Brian\OneDrive\Desktop\Box_Office1.csv'
#df.to_csv(Location_for_file_export, index=False)


#Location_for_file_export2 = r'C:\Users\Brian\PycharmProjects\notebooks\data_output\Box_Office1.xlsx'
Location_for_file_export2 = Path.cwd() / 'data_output' / 'Box_Office1.xlsx'
movie_df.to_excel(Location_for_file_export2, index=False)
print("Saving to:", Location_for_file_export2.resolve())
# Out:
# Saving to: /workspaces/movie_notebooks/data_output/Box_Office1.xlsx

# %%
print("End of Program: " + str(datetime.datetime.now().strftime("%I:%m %p")))
# Out:
# End of Program: 01:02 AM
